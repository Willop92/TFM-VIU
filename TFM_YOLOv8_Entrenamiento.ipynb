# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.180 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %% [markdown]
# ## 1. Detection
#
# YOLOv8 _detection_ models have no suffix and are the default YOLOv8 models, i.e. `yolov8n.pt` and are pretrained on COCO. See [Detection Docs](https://docs.ultralytics.com/tasks/detect/) for full details.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/trainSfinadaw.zip -d /content:

# %%
# !unzip -q /content/drive/MyDrive/trainSfin.zip -d /content/SDG:

# %%
import os
import numpy as np
BASE_FOLDER="/content/drive/MyDrive/Trabajo_final_VIU/Resources/TrainD/"
Lista_imagenes = os.listdir(BASE_FOLDER+'images/')
Lista_imagenes.sort()
print(len(Lista_imagenes))
# Out:
# 2020

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO:

# Load a model
model = YOLO('yolov8n.yaml')
model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data="/content/drive/MyDrive/Trabajo_final_VIU/Resources/YOLOV8/TFM-DETEC.yaml",
            batch=150, epochs=1500,
            save=True, save_period=1,optimizer='AdamW',imgsz=640)  # train the model
# model('https://ultralytics.com/images/bus.jpg')  # predict on an image
# Out:
#   File "<ipython-input-11-8b0ef11599c5>", line 2
#     from ultralytics import YOLO:
#                                 ^
# SyntaxError: invalid syntax

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO
PESO='/content/drive/MyDrive/Trabajo_final_VIU/Resources/Models/train_27.pt'
DATA='/content/drive/MyDrive/Trabajo_final_VIU/Resources/YOLOV8/TFM-28.yaml'
# Load a model
model = YOLO('yolov8n.yaml')
model = YOLO(PESO)  # load a pretrained YOLOv8n detection model
model.train(data=DATA,
            batch=50, epochs=500,
            save=True, save_period=10,optimizer='AdamW',imgsz=640)  # train the model
# model('https://ultralytics.com/images/bus.jpg')  # predict on an image
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO
PESO="/content/drive/MyDrive/Trabajo_final_VIU/Resources/Models/best (9).pt"
DATA="/content/drive/MyDrive/Trabajo_final_VIU/Resources/YOLOV8/TFM-DETEC.yaml"
# Load a model
model = YOLO('yolov8n.yaml')
model = YOLO(PESO)  # load a pretrained YOLOv8n detection model
model.train(data=DATA,
            batch=50, epochs=2500,
            save=True, save_period=10,optimizer='AdamW',imgsz=640)  # train the model
# model('https://ultralytics.com/images/bus.jpg')  # predict on an image
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')
model = YOLO('/content/runs/detect/train5/weights/best.pt')  # load a pretrained YOLOv8n detection model
model.train(data="/content/drive/MyDrive/Trabajo_final_VIU/Resources/YOLOV8/TFM-1.yaml",
            batch=100, epochs=500,
            save=True, save_period=1,optimizer='AdamW',imgsz=640)  # train the model
# model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')
model = YOLO('/content/runs/detect/train11/weights/best.pt')  # load a pretrained YOLOv8n detection model
model.train(data="/content/drive/MyDrive/Trabajo_final_VIU/Resources/YOLOV8/TFM-1.yaml",
            batch=100, epochs=500,
            save=True, save_period=1,optimizer='AdamW',imgsz=640)  # train the model
# model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')
model = YOLO('/content/runs/detect/train14/weights/best.pt')  # load a pretrained YOLOv8n detection model
model.train(data="/content/drive/MyDrive/Trabajo_final_VIU/Resources/YOLOV8/TFM-2.yaml",
            batch=100, epochs=500,
            save=True, save_period=1,optimizer='AdamW',imgsz=640)  # train the model
# model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')
model = YOLO('/content/runs/detect/train12/weights/best.pt')  # load a pretrained YOLOv8n detection model
model.train(data="/content/drive/MyDrive/Trabajo_final_VIU/Resources/YOLOV8/TFM-1.yaml",
            batch=100, epochs=500,
            save=True, save_period=1,optimizer='AdamW',imgsz=640)  # train the model
# model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %%
fimport locale
locale.getpreferredencoding = lambda: "UTF-8"
# !zip -r /content/drive/MyDrive/Trabajo_final_VIU/trainFinalyolo.zip /content/runs/detect/train4
# Out:
#   adding: content/runs/detect/train4/ (stored 0%)
#   adding: content/runs/detect/train4/train_batch1.jpg (deflated 5%)
#   adding: content/runs/detect/train4/args.yaml (deflated 51%)
#   adding: content/runs/detect/train4/PR_curve.png (deflated 18%)
#   adding: content/runs/detect/train4/labels_correlogram.jpg (deflated 40%)
#   adding: content/runs/detect/train4/confusion_matrix_normalized.png (deflated 35%)
#   adding: content/runs/detect/train4/val_batch0_labels.jpg (deflated 15%)
#   adding: content/runs/detect/train4/events.out.tfevents.1686763791.d90479173325.5369.1 (deflated 75%)
#   adding: content/runs/detect/train4/val_batch2_pred.jpg (deflated 16%)
#   adding: content/runs/detect/train4/val_batch1_pred.jpg (deflated 10%)
#   adding: content/runs/detect/train4/R_curve.png (deflated 18%)
#   adding: content/runs/detect/train4/P_curve.png (deflated 18%)
#   adding: content/runs/detect/train4/train_batch0.jpg (deflated 5%)
# ...

# %%
model.export()

# %%
model.export(format='torchscript')

# %%
model.export(format='saved_model')

# %% [markdown]
# #Entrenamiento final

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')
model = YOLO('/content/drive/MyDrive/Trabajo_final_VIU/YOLOV8/Model/bestTFM.pt')  # load a pretrained YOLOv8n detection model
model.train(data='/content/drive/MyDrive/Trabajo_final_VIU/YOLOV8/Model/TFM.yaml',
            batch=100, epochs=500,
            save=True, save_period=1,optimizer='AdamW',imgsz=640)  # train the model
# model('https://ultralytics.com/images/bus.jpg')  # predict on an image
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
from ultralytics import YOLO
#Test
model = YOLO('yolov8n.yaml')
model = YOLO("/content/drive/MyDrive/Trabajo_final_VIU/YOLOV8/Model/YOLOV8.pt")#cargar pesos
path = data='/content/drive/MyDrive/Trabajo_final_VIU/YOLOV8/Model/TFM.yaml'
results = model.val(data=path, save=True)  # generator of Results objects

# for result in results:
#     boxes = result.boxes  # Boxes object for bbox outputs
#     masks = result.masks  # Masks object for segmentation masks outputs
#     probs = result.probs  # Class probabilities for classification outputs

# display(boxes)
# display(masks)
# display(probs)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !zip -r /content/drive/MyDrive/Trabajo_final_VIU/ValTFM.zip /content/runs/detect/val
# Out:
#   adding: content/runs/detect/val/ (stored 0%)
#   adding: content/runs/detect/val/val_batch1_labels.jpg (deflated 10%)
#   adding: content/runs/detect/val/val_batch0_labels.jpg (deflated 11%)
#   adding: content/runs/detect/val/F1_curve.png (deflated 18%)
#   adding: content/runs/detect/val/val_batch0_pred.jpg (deflated 12%)
#   adding: content/runs/detect/val/R_curve.png (deflated 17%)
#   adding: content/runs/detect/val/val_batch1_pred.jpg (deflated 9%)
#   adding: content/runs/detect/val/P_curve.png (deflated 19%)
#   adding: content/runs/detect/val/confusion_matrix.png (deflated 35%)
#   adding: content/runs/detect/val/PR_curve.png (deflated 18%)
#   adding: content/runs/detect/val/confusion_matrix_normalized.png (deflated 34%)
#   adding: content/runs/detect/val/val_batch2_pred.jpg (deflated 8%)
#   adding: content/runs/detect/val/val_batch2_labels.jpg (deflated 8%)

# %%
from ultralytics import YOLO
#Test
model = YOLO('yolov8n.yaml')
model = YOLO("/content/drive/MyDrive/Trabajo_final_VIU/YOLOV8/Model/YOLOV8.pt")#cargar pesos
path = "/content/drive/MyDrive/Trabajo_final_VIU/YOLOV8/Dataset/test/images/"
results = model(path, save=True)  # generator of Results objects

for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    probs = result.probs  # Class probabilities for classification outputs

display(boxes)
display(masks)
display(probs)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %% [markdown]
# ADAW

# %%
from ultralytics import YOLO
#Test
model = YOLO('yolov8n.yaml')
model = YOLO('/content/content/runs/detect/train2/weights/best.pt')#cargar pesos
# Validate the model
metrics = model.val(plots=True)  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category

# %% [markdown]
# SDG

# %%
from ultralytics import YOLO
#Test
model = YOLO('yolov8n.yaml')
model = YOLO('/content/SDG/content/runs/detect/train/weights/best.pt')#cargar pesos
# Validate the model
metrics = model.val(plots=True)  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
display(metrics.box.maps )

# %% [markdown]
# Test

# %%
from ultralytics import YOLO
#Test

PESO='/content/drive/MyDrive/Trabajo_final_VIU/Resources/Models/bestTFM.pt'
DATA="/content/drive/MyDrive/Trabajo_final_VIU/Resources/YOLOV8/TFM-TEST0.yaml"

model = YOLO('yolov8n.yaml')
model = YOLO(PESO)#cargar pesos
# Validate the model
metrics = model.val(data=DATA,plots=True)  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
#Test
model = YOLO('yolov8n.yaml')
model = YOLO('/content/drive/MyDrive/Trabajo_final_VIU/YOLOV8/Model/YOLOV8.pt')#cargar pesos
# Validate the model
metrics = model.val(data="/content/drive/MyDrive/Trabajo_final_VIU/Resources/YOLOV8/TFM-TEST1.yaml",plots=True)  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
#Test
model = YOLO('yolov8n.yaml')
model = YOLO('/content/drive/MyDrive/Trabajo_final_VIU/Resources/Models/best (9).pt')#cargar pesos
# Validate the model
metrics = model.val(data="/content/drive/MyDrive/Trabajo_final_VIU/Resources/YOLOV8/TFM-TEST2.yaml",plots=True)  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
#Test
model = YOLO('yolov8n.yaml')
model = YOLO('/content/drive/MyDrive/Trabajo_final_VIU/Resources/Models/best (9).pt')#cargar pesos
# Validate the model
metrics = model.val(data="/content/drive/MyDrive/Trabajo_final_VIU/Resources/YOLOV8/TFM-TEST3.yaml",plots=True)  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
from ultralytics import YOLO
#Test
model = YOLO('yolov8n.yaml')
model = YOLO('/content/drive/MyDrive/Trabajo_final_VIU/Resources/Models/best (9).pt')#cargar pesos
path = "/content/drive/MyDrive/Trabajo_final_VIU/Resources/Test0/images"
results = model(path, save=True)  # generator of Results objects

for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    probs = result.probs  # Class probabilities for classification outputs

display(boxes)
display(masks)
display(probs)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
from PIL import Image

# Read image
img = Image.open('/content/datasets/coco128/images/train2017/000000000009.jpg')
display(np.array(img))
# Output Images
img.show()

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np

# Read Images
img = mpimg.imread('/content/datasets/coco128/images/train2017/000000000009.jpg','rgb')
# display(img)
# Output Images
plt.imshow(img)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
display(len(data_bus[0].orig_img[0]))
plt.imshow(data_bus[0].orig_img)

# %% [markdown]
# ## 4. Pose
#
# YOLOv8 _pose_ models use the `-pose` suffix, i.e. `yolov8n-pose.pt` and are pretrained on COCO Keypoints. See [Pose Docs](https://docs.ultralytics.com/tasks/pose/) for full details.

# %%
# Load YOLOv8n-pose, train it on COCO8-pose for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n-pose.pt')  # load a pretrained YOLOv8n classification model
model.train(data='coco8-pose.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# Git clone install (for development)
# !git clone https://github.com/ultralytics/ultralytics -b main
# %pip install -qe ultralytics

# %%
# Run YOLOv8 tests (git clone install only)
# !pytest ultralytics/tests

# %%
# Validate multiple models
for x in 'nsmlx':
  # !yolo val model=yolov8{x}.pt data=coco.yaml
